# %%
import sys
sys.path.append('/Users/fateme/Desktop/CeeNous/Sideband/src')
from sideband import find_signals_sideband

# %%
find_signals_sideband(
    '/Users/fateme/Desktop/CeeNous/Sideband/data/Faulty/2511RM1')
# Out:
# {'2511RM1   -18  G-4V_ Vel (4_29_2024 10_31_03) - Time Signal.txt': [{'gmf': 31.24999953433868,
#    'score': 20.92,
#    'sidebands': {100: [], 200: [168, 211, 222]},
#    'spacing': 3.4374999487772584},
#   {'gmf': 164.06249755527807,
#    'score': 55.69,
#    'sidebands': {525: [342,
#      365,
#      388,
#      411,
#      434,
#      457,
#      479,
#      548,
#      594,
#      616,
#      662,
#      708,
#      731],
#     1050: [959,
#      982,
#      1005,
#      1027,
#      1073,
#      1096,
#      1119,
#      1141,
#      1164,
#      1187,
#      1210,
#      1233,
#      1256,
#      1279],
#     1575: [1438,
#      1461,
#      1484,
#      1507,
#      1530,
#      1553,
#      1598,
#      1621,
#      1644,
#      1667,
#      1689,
#      1712,
#      1735,
#      1758,
#      1781]},
#    'spacing': 7.179687473049848},
#   {'gmf': 314.0624953201037,
#    'score': 71.97,
#    'sidebands': {1005: [959,
#      982,
#      1027,
#      1050,
#      1073,
# ...
